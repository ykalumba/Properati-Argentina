# %% [markdown]
# ### Prepare Data

# %% [markdown]
# #### Import

# %%
import warnings 

import pandas as pd
import seaborn as sns
from category_encoders import OneHotEncoder
from ipywidgets import Dropdown, FloatSlider, IntSlider, interact
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.pipeline import make_pipeline

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
# df = pd.read_csv("entrenamiento.csv")

# %%
import csv

input_file = "entrenamiento.csv"
output_file = "entrenamiento_parsed.csv"

with open(input_file, "r", encoding="utf-8", newline="") as infile, \
     open(output_file, "w", encoding="utf-8", newline="") as outfile:

    reader = csv.reader(infile)
    writer = csv.writer(outfile)

    header = next(reader)
    writer.writerow(header)

    repaired = 0
    valid = 0

    for row in reader:

        if len(row) == 25:
            writer.writerow(row)
            valid += 1

        elif len(row) > 25:
            # Reconstruct description
            parsed_row = (row[:21]+ [",".join(row[21:-3])]+ row[-3:])

            writer.writerow(parsed_row)
            repaired += 1

# %%
data = pd.read_csv("entrenamiento_parsed.csv")
# data.info()

# %%
# data.head()

# %% [markdown]
# ##### Chi-square test

# %%
from scipy.stats import chi2_contingency
import numpy as np

# %% [markdown]
# ### Hypotheses
#
# **Null hypothesis** (H₀): There is no relationship between `property_type` and `operation_type` (they are independent).
#
# **Alternative hypothesis** (H₁): There is a significant relationship between `property_type` and `operation_type`.

# %%
# Contingency table
table = pd.crosstab(data['property_type'], data['operation_type'])

# %%
# Chi-square test
chi2, p, dof, expected = chi2_contingency(table)

print("Chi-square statistic:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
# Out:
# Chi-square statistic: 146910.8623474115
# p-value: 0.0
# Degrees of freedom: 18

# %% [markdown]
# Since p-value = 0 < 0.05 → Reject H₀ ; hence a significant relationship between `property_type` and `operation_type`.

# %%
# Effect size: Cramér's V
n = table.sum().sum()
phi2 = chi2 / n
r, k = table.shape
cramers_v = np.sqrt(phi2 / min(k-1, r-1))

print("Cramér's V:", cramers_v)
# Out:
# Cramér's V: 0.2539563372551448

# %%
# columns = ['lat', 'lon','l1', 'l2', 'l3', 'l4', 'rooms', 'bedrooms', 'bathrooms','surface_total', 'surface_covered', 'currency', 'price']
columns = ['lat', 'lon','l1', 'l2', 'l3', 'l4', 'surface_total', 'surface_covered', 'currency', 'price', 'property_type', 'operation_type']

# %%
df = data[columns]

# %%
# df.describe()

# %%
def preprocess(df):
    # Create a copy to prevent SettingWithCopyWarning
    df_processed = df.copy()

    # Swap swapped lat/lon column headers
    df_processed = df_processed.rename(columns={"lat": "lon", "lon": "lat"})

    # Ensure price is numeric
    df_processed["price"] = pd.to_numeric(df_processed["price"], errors="coerce")

    # Convert all currencies to USD as at August 10, 2026
    exchange_rates = {"USD": 1.0, "ARS": 1498.25, "UYU": 40.25, "PEN": 3.38}
    df_processed["price_usd"] = df_processed["price"] / df_processed["currency"].map(exchange_rates)

    # Subset data: Properties in "Capital Federal" priced above 500,000 USD
    mask_cf = df_processed["l2"] == "Capital Federal"
    mask_price = df_processed["price_usd"] > 500_000
    df_processed = df_processed[mask_cf & mask_price]

    # Subset data: Remove outliers for "surface_covered"
    low, high = df_processed["surface_covered"].quantile([0.1, 0.9])
    mask_area = df_processed["surface_covered"].between(low, high)
    df_processed = df_processed[mask_area]

    # Rename column 'l3'
    df_processed = df_processed.rename(columns={"l3": "neighborhood"})

    # Drop columns with high nulls, multicollinearity, redundancy
    # df_processed = df_processed.drop(columns=["l4", "rooms"])
    df_processed = df_processed.drop(columns=["l4"])


    # Drop columns
    df_processed = df_processed.drop(columns=["l1", "l2", "currency", "price"])

    # Fill Numeric columns by → median
    num_cols = df_processed.select_dtypes(include="number").columns
    df_processed[num_cols] = SimpleImputer(strategy="median").fit_transform(df_processed[num_cols])
    
    # Fill Categorical columns by → most frequent value
    cat_cols = df_processed.select_dtypes(exclude="number").columns
    df_processed[cat_cols] = SimpleImputer(strategy="most_frequent").fit_transform(df_processed[cat_cols])

    return df_processed

# %%
df_processed = preprocess(df)

# %%
df_processed.head()
# Out:
#            lon        lat   neighborhood  surface_total  surface_covered  \
# 92  -58.421588 -34.588131  Puerto Madero          135.0            135.0
# 136 -58.447588 -34.566724       Belgrano          206.0            130.0
# 242 -58.360130 -34.613297  Puerto Madero          150.0            138.0
# 310 -58.363594 -34.604894  Puerto Madero          198.0            187.0
# 400 -58.360806 -34.610180  Puerto Madero          188.0            188.0
#
#     property_type operation_type  price_usd
# 92   Departamento          Venta   890000.0
# 136  Departamento          Venta   990000.0
# 242  Departamento          Venta  1020000.0
# 310  Departamento          Venta  1200000.0
# 400  Departamento          Venta  1200000.0

# %%
df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9674 entries, 92 to 1138943
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   lon              9674 non-null   float64
#  1   lat              9674 non-null   float64
#  2   neighborhood     9674 non-null   object
#  3   surface_total    9674 non-null   float64
#  4   surface_covered  9674 non-null   float64
#  5   property_type    9674 non-null   object
#  6   operation_type   9674 non-null   object
#  7   price_usd        9674 non-null   float64
# dtypes: float64(5), object(3)
# memory usage: 680.2+ KB

# %%
neighborhood_prices = (df_processed.groupby("neighborhood")["price_usd"].median().sort_values(ascending=False))
neighborhood_prices.head()
# Out:
# neighborhood
# Puerto Madero       1250000.0
# Velez Sarsfield     1050000.0
# Parque Patricios     980000.0
# Catalinas            960000.0
# Once                 930000.0
# Name: price_usd, dtype: float64

# %% [markdown]
# **Median Price** : Puerto Madero has a median listing price of $1.25M, meaning half of listings are above and half below this value.
#
# **Neighborhood Hierarchy** : Puerto Madero ranks highest, followed by Vélez Sarsfield ($1.05M), Parque Patricios ($980K), Catalinas ($960K), and   Once ($930K).
#
# **Key Insight** : Price differences reflect both location and property composition, with luxury residential, office, and commercial properties influencing neighborhood medians.

# %%
df_processed[["surface_total", "surface_covered", "price_usd"]].corr()
# Out:
#                  surface_total  surface_covered  price_usd
# surface_total         1.000000         0.609734   0.228925
# surface_covered       0.609734         1.000000   0.381625
# price_usd             0.228925         0.381625   1.000000

# %%
sns.scatterplot(data=df_processed, x = "surface_total", y = "price_usd");

# %%
df_processed.nlargest(5, "price_usd")[["property_type", "neighborhood", "surface_total", "price_usd"]]
# Out:
#         property_type          neighborhood  surface_total   price_usd
# 328027           Lote             San Telmo          252.0  19000000.0
# 224380   Departamento              Belgrano          690.0   8500000.0
# 254999   Departamento               Palermo          410.0   8000000.0
# 918001        Oficina  Centro / Microcentro          420.0   7200000.0
# 1064479       Oficina  Centro / Microcentro          420.0   7200000.0

# %% [markdown]
# #### Does property size explain price?

# %%
# sns.scatterplot(data=df_processed, x="surface_covered", y="price_usd").set(yscale="log");

sns.scatterplot(
    data=df_processed,
    x="surface_covered", y="price_usd").set(xlabel="Surface Area Covered (m²)",
                                            ylabel="Property Price ($)", yscale="log");

# %% [markdown]
# **Positive relationship**: Larger properties generally have higher prices, indicating that surface area contributes to property value.
#
# **High price variation**: Properties of similar sizes can have substantially different prices, showing that size alone does not explain price.
#
# **Key conclusion**: Property size is an important price driver, but location, property type, and luxury characteristics also substantially influence property prices.
#
# Larger properties generally command higher prices, but surface area alone does not adequately explain property price. The substantial variation at similar sizes indicates that location and property characteristics are important additional price determinants.

# %% [markdown]
# #### High-value properties (top 10% of price_usd)

# %%
high_value = df_processed[df_processed["price_usd"] >= df_processed["price_usd"].quantile(0.90)]

high_value["property_type"].value_counts(normalize=True)
# Out:
# property_type
# Departamento       0.617589
# Casa               0.131423
# Oficina            0.102767
# Local comercial    0.076087
# Otro               0.029644
# Depósito           0.023715
# Lote               0.017787
# PH                 0.000988
# Name: proportion, dtype: float64

# %% [markdown]
# The top 10% of high-value properties are strongly dominated by apartments (Departamento), which account for the greatest proportion (61.8%) of the luxury market. Houses follow at 13.1%, while offices (10.3%) and commercial stores (7.6%) represent significant commercial segments.
#
# Overall, residential properties account for roughly 75% of high-value listings, compared with about 20% for commercial properties. In contrast, PH properties contribute less than 0.1%, indicating that they are rarely represented in the highest price segment.
#
# Key insight: The high-value Properati market is primarily an urban luxury apartment market, with houses and prime commercial properties forming secondary segments.

# %%
# df_processed.describe()

# %%
corr = df_processed.select_dtypes("number").drop(columns="price_usd").corr()
sns.heatmap(corr);

# %% [markdown]
# ### Split Data

# %%
target = "price_usd"

# %%
features= ["lat", "lon", "neighborhood", "surface_covered"]
X_train=df_processed[features]
y_train=df_processed[target]

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Baseline

# %%
y_mean = y_train.mean()
print("Mean property price:", y_mean)
y_pred_baseline = [y_mean]*len(y_train)
print("Baseline MAE:", mean_absolute_error(y_train,y_pred_baseline))
# Out:
# Mean property price: 1059141.767521191
# Baseline MAE: 469877.2396421886

# %% [markdown]
# ### Iterate

# %% [raw]
# model = make_pipeline(SimpleImputer(), OneHotEncoder(use_cat_names=True), Ridge())
# model.fit(X_train, y_train)

# %%
# from category_encoders import OneHotEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
num_cols = X_train.select_dtypes(include="number").columns
cat_cols = X_train.select_dtypes(exclude="number").columns

# Preprocessing
preprocessor = ColumnTransformer(
    transformers=[("num", SimpleImputer(strategy="median"), num_cols), ("cat", make_pipeline(SimpleImputer(strategy="most_frequent"), 
                                                                                             OneHotEncoder(handle_unknown="ignore")), cat_cols)])
# Complete model
model = make_pipeline(preprocessor, Ridge())

# Fit
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   SimpleImputer(strategy='median'),
#                                                   Index(['lat', 'lon', 'surface_covered'], dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   Index(['neighborhood'], dtype='object'))])),
#                 ('ridge', Ridge())])

# %%
y_pred_training = model.predict(X_train)
print("Training MAE:", mean_absolute_error(y_train, y_pred_training))
# Out:
# Training MAE: 366137.1806015615

# %% [markdown]
# ## Communicate Results

# %%
def make_prediction(area, lat, lon, neighborhood):
    data = {"surface_covered":area, "lat":lat, "lon":lon, "neighborhood":neighborhood}
    
    df_processed=pd.DataFrame(data,index=[0])
    prediction = model.predict(df_processed).round(2)
    return f"Predicted property price: ${prediction}"

# %%
make_prediction(110, -34.60, -58.46, "Villa Crespo")
# Out:
# 'Predicted property price: $[118888.48]'

# %%
interact(
    make_prediction,
    area=IntSlider(
        min=X_train["surface_covered"].min(),
        max=X_train["surface_covered"].max(),
        value=X_train["surface_covered"].mean(),
    ),
    lat=FloatSlider(
        min=X_train["lat"].min(),
        max=X_train["lat"].max(),
        step=0.01,
        value=X_train["lat"].mean(),
    ),
    lon=FloatSlider(
        min=X_train["lon"].min(),
        max=X_train["lon"].max(),
        step=0.01,
        value=X_train["lon"].mean(),
    ),
    neighborhood=Dropdown(options=sorted(X_train["neighborhood"].unique())),
);
# Out:
# interactive(children=(IntSlider(value=264, description='area', max=689, min=116), FloatSlider(value=-34.593727…

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/andrew-kalumba-harris/">ANDREW KALUMBA YIGGA</a><br>
# <a href =""> </a>
#
#
# | Date (YYYY-MM-DD) | Prepared By     |
# | ----------------- | --------------  |
# | 2026-08-16        | Author          |
#
#
# ## <h3 align="center">  Data Science 2026. <h3/>
